# %%
import pandas as pd
import os
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
stock_data = "/Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources"
read_files = glob.glob(os.path.join(stock_data, "*.csv"))

np_array_values = []
# Date = []
# Open = []
# High = []
# Low = []
# Close = []
# Adj_Close = []
for file in read_files:
    data = pd.read_csv(file)
    np_array_values.append(data)
    #Date.append(data['Date'])
    print(file)
# Out:
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/ADI.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/AMT.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/CCI.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/ERIC.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/AVGO.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/QCOM.csv
# /Users/ulissesmiranda/Documents/GitHub/Stock_5g_analyses/Resources/TMUS.csv

# %%
np_array_values
# Out:
# [           Date        Open        High         Low       Close   Adj Close  \
#  0    2019-12-20  120.180000  120.220001  117.900002  119.820000  117.399254
#  1    2019-12-23  120.000000  120.550003  119.029999  119.169998  116.762390
#  2    2019-12-24  119.260002  119.879997  119.110001  119.720001  117.301277
#  3    2019-12-26  119.669998  120.129997  119.260002  119.730003  117.311081
#  4    2019-12-27  119.720001  120.000000  118.989998  119.449997  117.036736
#  ..          ...         ...         ...         ...         ...         ...
#  247  2020-12-14  142.059998  143.929993  141.660004  142.330002  142.330002
#  248  2020-12-15  145.259995  145.259995  143.490005  144.059998  144.059998
#  249  2020-12-16  144.759995  144.759995  141.570007  142.800003  142.800003
#  250  2020-12-17  143.550003  143.869995  142.610001  143.779999  143.779999
#  251  2020-12-18  144.380005  145.000000  143.440002  144.559998  144.559998
#
#        Volume
#  0    4449000
# ...

# %%
merge_values = np.vstack(np_array_values)
data2= pd.DataFrame(merge_values)
data2
# Out:
#                0       1       2       3       4        5        6
# 0     2019-12-20  120.18  120.22   117.9  119.82  117.399  4449000
# 1     2019-12-23     120  120.55  119.03  119.17  116.762  1565700
# 2     2019-12-24  119.26  119.88  119.11  119.72  117.301   487800
# 3     2019-12-26  119.67  120.13  119.26  119.73  117.311   912600
# 4     2019-12-27  119.72     120  118.99  119.45  117.037  1360900
# ...          ...     ...     ...     ...     ...      ...      ...
# 1759  2020-12-14  131.02  132.97  129.23  129.36   129.36  5296700
# 1760  2020-12-15   129.7  130.71  128.78     130      130  2906300
# 1761  2020-12-16  130.65  130.65  129.11  129.81   129.81  3262000
# 1762  2020-12-17  130.32  130.76  129.65  130.01   130.01  4132200
# 1763  2020-12-18   130.3  132.14  129.51  131.92   131.92  8782600
#
# [1764 rows x 7 columns]

# %%
stock_data = "Resources/AMT.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_AMT = pd.read_csv(stock_data)
stock_data_df_AMT["ticker"] = f'AMT'
stock_data_df_AMT
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  226.800003  228.279999  224.500000  227.740005  223.757690
# 1    2019-12-23  227.110001  229.979996  226.399994  226.970001  223.001144
# 2    2019-12-24  227.139999  228.039993  226.259995  227.080002  223.109222
# 3    2019-12-26  226.690002  227.869995  225.570007  227.869995  224.885620
# 4    2019-12-27  228.520004  229.289993  227.550003  229.080002  226.079803
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  220.970001  222.429993  216.399994  216.720001  216.720001
# 248  2020-12-15  217.080002  218.360001  215.550003  217.250000  217.250000
# 249  2020-12-16  218.279999  219.800003  215.679993  219.619995  219.619995
# 250  2020-12-17  221.100006  223.600006  220.130005  222.710007  222.710007
# 251  2020-12-18  222.179993  223.229996  219.839996  221.520004  221.520004
#
#       Volume ticker
# 0    3333100    AMT
# ...

# %%
stock_data_df_AMT['Change'] = stock_data_df_AMT.groupby('ticker').Close.pct_change()
stock_data_df_AMT
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  226.800003  228.279999  224.500000  227.740005  223.757690
# 1    2019-12-23  227.110001  229.979996  226.399994  226.970001  223.001144
# 2    2019-12-24  227.139999  228.039993  226.259995  227.080002  223.109222
# 3    2019-12-26  226.690002  227.869995  225.570007  227.869995  224.885620
# 4    2019-12-27  228.520004  229.289993  227.550003  229.080002  226.079803
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  220.970001  222.429993  216.399994  216.720001  216.720001
# 248  2020-12-15  217.080002  218.360001  215.550003  217.250000  217.250000
# 249  2020-12-16  218.279999  219.800003  215.679993  219.619995  219.619995
# 250  2020-12-17  221.100006  223.600006  220.130005  222.710007  222.710007
# 251  2020-12-18  222.179993  223.229996  219.839996  221.520004  221.520004
#
#       Volume ticker    Change
# ...

# %%
stock_data = "Resources/ADI.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_ADI = pd.read_csv(stock_data)
stock_data_df_ADI["ticker"] = f'ADI'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_ADI
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  120.180000  120.220001  117.900002  119.820000  117.399254
# 1    2019-12-23  120.000000  120.550003  119.029999  119.169998  116.762390
# 2    2019-12-24  119.260002  119.879997  119.110001  119.720001  117.301277
# 3    2019-12-26  119.669998  120.129997  119.260002  119.730003  117.311081
# 4    2019-12-27  119.720001  120.000000  118.989998  119.449997  117.036736
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  142.059998  143.929993  141.660004  142.330002  142.330002
# 248  2020-12-15  145.259995  145.259995  143.490005  144.059998  144.059998
# 249  2020-12-16  144.759995  144.759995  141.570007  142.800003  142.800003
# 250  2020-12-17  143.550003  143.869995  142.610001  143.779999  143.779999
# 251  2020-12-18  144.380005  145.000000  143.440002  144.559998  144.559998
#
#       Volume ticker
# 0    4449000    ADI
# ...

# %%
stock_data_df_ADI['Change'] = stock_data_df_ADI.groupby('ticker').Close.pct_change()
stock_data_df_ADI
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  120.180000  120.220001  117.900002  119.820000  117.399254
# 1    2019-12-23  120.000000  120.550003  119.029999  119.169998  116.762390
# 2    2019-12-24  119.260002  119.879997  119.110001  119.720001  117.301277
# 3    2019-12-26  119.669998  120.129997  119.260002  119.730003  117.311081
# 4    2019-12-27  119.720001  120.000000  118.989998  119.449997  117.036736
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  142.059998  143.929993  141.660004  142.330002  142.330002
# 248  2020-12-15  145.259995  145.259995  143.490005  144.059998  144.059998
# 249  2020-12-16  144.759995  144.759995  141.570007  142.800003  142.800003
# 250  2020-12-17  143.550003  143.869995  142.610001  143.779999  143.779999
# 251  2020-12-18  144.380005  145.000000  143.440002  144.559998  144.559998
#
#       Volume ticker    Change
# ...

# %%
stock_data = "Resources/CCI.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_CCI = pd.read_csv(stock_data)
stock_data_df_CCI["ticker"] = f'CCI'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_CCI
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  142.050003  142.460007  140.500000  142.000000  137.691223
# 1    2019-12-23  142.320007  142.830002  140.380005  140.580002  136.314331
# 2    2019-12-24  140.550003  140.869995  139.500000  140.039993  135.790695
# 3    2019-12-26  140.270004  140.729996  139.740005  140.600006  136.333725
# 4    2019-12-27  141.110001  141.500000  140.320007  141.080002  136.799164
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  157.910004  158.899994  154.919998  155.190002  155.190002
# 248  2020-12-15  155.300003  156.009995  154.350006  155.410004  155.410004
# 249  2020-12-16  155.880005  157.250000  153.520004  154.119995  154.119995
# 250  2020-12-17  156.279999  157.529999  155.020004  155.750000  155.750000
# 251  2020-12-18  154.820007  155.800003  152.089996  153.809998  153.809998
#
#       Volume ticker
# 0    3225900    CCI
# ...

# %%
stock_data_df_CCI['Change'] = stock_data_df_CCI.groupby('ticker').Close.pct_change()
stock_data_df_CCI
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  142.050003  142.460007  140.500000  142.000000  137.691223
# 1    2019-12-23  142.320007  142.830002  140.380005  140.580002  136.314331
# 2    2019-12-24  140.550003  140.869995  139.500000  140.039993  135.790695
# 3    2019-12-26  140.270004  140.729996  139.740005  140.600006  136.333725
# 4    2019-12-27  141.110001  141.500000  140.320007  141.080002  136.799164
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  157.910004  158.899994  154.919998  155.190002  155.190002
# 248  2020-12-15  155.300003  156.009995  154.350006  155.410004  155.410004
# 249  2020-12-16  155.880005  157.250000  153.520004  154.119995  154.119995
# 250  2020-12-17  156.279999  157.529999  155.020004  155.750000  155.750000
# 251  2020-12-18  154.820007  155.800003  152.089996  153.809998  153.809998
#
#       Volume ticker    Change
# ...

# %%
stock_data = "Resources/ERIC.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_ERIC = pd.read_csv(stock_data)
stock_data_df_ERIC["ticker"] = f'ERIC'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_ERIC
# Out:
#            Date   Open   High    Low  Close  Adj Close   Volume ticker
# 0    2019-12-20   8.86   8.86   8.77   8.80   8.647130  5704800   ERIC
# 1    2019-12-23   8.79   8.85   8.78   8.84   8.686436  3569800   ERIC
# 2    2019-12-24   8.86   8.89   8.81   8.86   8.706087  1116800   ERIC
# 3    2019-12-26   8.89   8.93   8.86   8.88   8.725739  2061000   ERIC
# 4    2019-12-27   8.90   8.90   8.84   8.86   8.706087  2449700   ERIC
# ..          ...    ...    ...    ...    ...        ...      ...    ...
# 247  2020-12-14  11.86  11.89  11.69  11.71  11.710000  4643900   ERIC
# 248  2020-12-15  11.90  12.00  11.86  12.00  12.000000  5054200   ERIC
# 249  2020-12-16  11.96  12.00  11.88  11.92  11.920000  3784800   ERIC
# 250  2020-12-17  12.15  12.19  12.01  12.06  12.060000  5515500   ERIC
# 251  2020-12-18  11.95  12.02  11.82  11.90  11.900000  5344500   ERIC
#
# [252 rows x 8 columns]

# %%
stock_data_df_ERIC['Change'] = stock_data_df_ERIC.groupby('ticker').Close.pct_change()
stock_data_df_ERIC
# Out:
#            Date   Open   High    Low  Close  Adj Close   Volume ticker  \
# 0    2019-12-20   8.86   8.86   8.77   8.80   8.647130  5704800   ERIC
# 1    2019-12-23   8.79   8.85   8.78   8.84   8.686436  3569800   ERIC
# 2    2019-12-24   8.86   8.89   8.81   8.86   8.706087  1116800   ERIC
# 3    2019-12-26   8.89   8.93   8.86   8.88   8.725739  2061000   ERIC
# 4    2019-12-27   8.90   8.90   8.84   8.86   8.706087  2449700   ERIC
# ..          ...    ...    ...    ...    ...        ...      ...    ...
# 247  2020-12-14  11.86  11.89  11.69  11.71  11.710000  4643900   ERIC
# 248  2020-12-15  11.90  12.00  11.86  12.00  12.000000  5054200   ERIC
# 249  2020-12-16  11.96  12.00  11.88  11.92  11.920000  3784800   ERIC
# 250  2020-12-17  12.15  12.19  12.01  12.06  12.060000  5515500   ERIC
# 251  2020-12-18  11.95  12.02  11.82  11.90  11.900000  5344500   ERIC
#
#        Change
# 0         NaN
# 1    0.004545
# 2    0.002262
# 3    0.002257
# 4   -0.002252
# ..        ...
# ...

# %%
stock_data = "Resources/AVGO.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_AVGO = pd.read_csv(stock_data)
stock_data_df_AVGO["ticker"] = f'AVGO'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_AVGO
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  322.470001  322.470001  316.910004  319.000000  305.065399
# 1    2019-12-23  320.540009  322.329987  317.609985  319.529999  305.572235
# 2    2019-12-24  320.000000  320.679993  319.010010  320.500000  306.499878
# 3    2019-12-26  321.269989  321.739990  316.820007  317.980011  304.089966
# 4    2019-12-27  319.299988  319.350006  315.220001  316.529999  302.703278
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  406.529999  414.299988  406.000000  411.799988  408.320801
# 248  2020-12-15  415.279999  419.390015  412.989990  418.059998  414.527924
# 249  2020-12-16  418.000000  427.149994  416.959991  424.899994  421.310120
# 250  2020-12-17  426.500000  430.010010  424.549988  426.100006  422.500000
# 251  2020-12-18  424.799988  435.649994  422.000000  434.559998  434.559998
#
#       Volume ticker
# 0    5054000   AVGO
# ...

# %%
stock_data_df_AVGO['Change'] = stock_data_df_AVGO.groupby('ticker').Close.pct_change()
stock_data_df_AVGO
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  322.470001  322.470001  316.910004  319.000000  305.065399
# 1    2019-12-23  320.540009  322.329987  317.609985  319.529999  305.572235
# 2    2019-12-24  320.000000  320.679993  319.010010  320.500000  306.499878
# 3    2019-12-26  321.269989  321.739990  316.820007  317.980011  304.089966
# 4    2019-12-27  319.299988  319.350006  315.220001  316.529999  302.703278
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  406.529999  414.299988  406.000000  411.799988  408.320801
# 248  2020-12-15  415.279999  419.390015  412.989990  418.059998  414.527924
# 249  2020-12-16  418.000000  427.149994  416.959991  424.899994  421.310120
# 250  2020-12-17  426.500000  430.010010  424.549988  426.100006  422.500000
# 251  2020-12-18  424.799988  435.649994  422.000000  434.559998  434.559998
#
#       Volume ticker    Change
# ...

# %%
stock_data = "Resources/QCOM.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_QCOM = pd.read_csv(stock_data)
stock_data_df_QCOM["ticker"] = f'QCOM'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_QCOM
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20   88.820000   89.849998   88.180000   88.849998   86.631882
# 1    2019-12-23   89.010002   89.330002   88.250000   88.449997   86.241867
# 2    2019-12-24   88.620003   88.809998   87.980003   88.769997   86.553879
# 3    2019-12-26   88.919998   88.959999   88.000000   88.400002   86.193123
# 4    2019-12-27   88.900002   88.949997   88.089996   88.800003   86.583130
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  144.899994  147.750000  143.330002  146.289993  146.289993
# 248  2020-12-15  149.369995  149.919998  147.100006  148.360001  148.360001
# 249  2020-12-16  149.139999  150.440002  146.710007  149.740005  149.740005
# 250  2020-12-17  150.869995  151.229996  148.380005  149.529999  149.529999
# 251  2020-12-18  150.789993  150.789993  146.119995  147.419998  147.419998
#
#        Volume ticker
# 0    17538000   QCOM
# ...

# %%
stock_data_df_QCOM['Change'] = stock_data_df_QCOM.groupby('ticker').Close.pct_change()
stock_data_df_QCOM
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20   88.820000   89.849998   88.180000   88.849998   86.631882
# 1    2019-12-23   89.010002   89.330002   88.250000   88.449997   86.241867
# 2    2019-12-24   88.620003   88.809998   87.980003   88.769997   86.553879
# 3    2019-12-26   88.919998   88.959999   88.000000   88.400002   86.193123
# 4    2019-12-27   88.900002   88.949997   88.089996   88.800003   86.583130
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  144.899994  147.750000  143.330002  146.289993  146.289993
# 248  2020-12-15  149.369995  149.919998  147.100006  148.360001  148.360001
# 249  2020-12-16  149.139999  150.440002  146.710007  149.740005  149.740005
# 250  2020-12-17  150.869995  151.229996  148.380005  149.529999  149.529999
# 251  2020-12-18  150.789993  150.789993  146.119995  147.419998  147.419998
#
#        Volume ticker    Change
# ...

# %%
stock_data = "Resources/TMUS.csv"

# Read Purchasing File and store into Pandas data frame

stock_data_df_TMUS = pd.read_csv(stock_data)
stock_data_df_TMUS["ticker"] = f'TMUS'
#new_df_AMT = stock_data_df_AMT [['Date', 'Close', 'ticker']]
#new_df_AMT.head()
stock_data_df_TMUS
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20   77.930000   77.930000   77.019997   77.400002   77.400002
# 1    2019-12-23   77.470001   77.559998   76.919998   76.959999   76.959999
# 2    2019-12-24   77.050003   77.410004   76.919998   77.320000   77.320000
# 3    2019-12-26   77.459999   77.540001   77.309998   77.400002   77.400002
# 4    2019-12-27   77.320000   77.500000   77.010002   77.239998   77.239998
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  131.020004  132.970001  129.229996  129.360001  129.360001
# 248  2020-12-15  129.699997  130.710007  128.779999  130.000000  130.000000
# 249  2020-12-16  130.649994  130.649994  129.110001  129.809998  129.809998
# 250  2020-12-17  130.320007  130.759995  129.649994  130.009995  130.009995
# 251  2020-12-18  130.300003  132.139999  129.509995  131.919998  131.919998
#
#       Volume ticker
# 0    5944300   TMUS
# ...

# %%
stock_data_df_TMUS['Change'] = stock_data_df_TMUS.groupby('ticker').Close.pct_change()
stock_data_df_TMUS
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20   77.930000   77.930000   77.019997   77.400002   77.400002
# 1    2019-12-23   77.470001   77.559998   76.919998   76.959999   76.959999
# 2    2019-12-24   77.050003   77.410004   76.919998   77.320000   77.320000
# 3    2019-12-26   77.459999   77.540001   77.309998   77.400002   77.400002
# 4    2019-12-27   77.320000   77.500000   77.010002   77.239998   77.239998
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  131.020004  132.970001  129.229996  129.360001  129.360001
# 248  2020-12-15  129.699997  130.710007  128.779999  130.000000  130.000000
# 249  2020-12-16  130.649994  130.649994  129.110001  129.809998  129.809998
# 250  2020-12-17  130.320007  130.759995  129.649994  130.009995  130.009995
# 251  2020-12-18  130.300003  132.139999  129.509995  131.919998  131.919998
#
#       Volume ticker    Change
# ...

# %%
frames = [stock_data_df_AMT, stock_data_df_ADI, stock_data_df_CCI, stock_data_df_ERIC, stock_data_df_AVGO, stock_data_df_QCOM, stock_data_df_TMUS]
result1 = pd.concat(frames)
result1
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  226.800003  228.279999  224.500000  227.740005  223.757690
# 1    2019-12-23  227.110001  229.979996  226.399994  226.970001  223.001144
# 2    2019-12-24  227.139999  228.039993  226.259995  227.080002  223.109222
# 3    2019-12-26  226.690002  227.869995  225.570007  227.869995  224.885620
# 4    2019-12-27  228.520004  229.289993  227.550003  229.080002  226.079803
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  131.020004  132.970001  129.229996  129.360001  129.360001
# 248  2020-12-15  129.699997  130.710007  128.779999  130.000000  130.000000
# 249  2020-12-16  130.649994  130.649994  129.110001  129.809998  129.809998
# 250  2020-12-17  130.320007  130.759995  129.649994  130.009995  130.009995
# 251  2020-12-18  130.300003  132.139999  129.509995  131.919998  131.919998
#
#       Volume ticker    Change
# ...

# %%
result['Change'] = result.groupby('ticker').Close.pct_change()
result
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  226.800003  228.279999  224.500000  227.740005  223.757690
# 1    2019-12-23  227.110001  229.979996  226.399994  226.970001  223.001144
# 2    2019-12-24  227.139999  228.039993  226.259995  227.080002  223.109222
# 3    2019-12-26  226.690002  227.869995  225.570007  227.869995  224.885620
# 4    2019-12-27  228.520004  229.289993  227.550003  229.080002  226.079803
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  131.020004  132.970001  129.229996  129.360001  129.360001
# 248  2020-12-15  129.699997  130.710007  128.779999  130.000000  130.000000
# 249  2020-12-16  130.649994  130.649994  129.110001  129.809998  129.809998
# 250  2020-12-17  130.320007  130.759995  129.649994  130.009995  130.009995
# 251  2020-12-18  130.300003  132.139999  129.509995  131.919998  131.919998
#
#       Volume ticker    Change
# ...

# %%
new_result = result [['Date', 'Close', 'ticker']]
new_result
# Out:
#            Date       Close ticker
# 0    2019-12-20  227.740005    AMT
# 1    2019-12-23  226.970001    AMT
# 2    2019-12-24  227.080002    AMT
# 3    2019-12-26  227.869995    AMT
# 4    2019-12-27  229.080002    AMT
# ..          ...         ...    ...
# 247  2020-12-14  129.360001   TMUS
# 248  2020-12-15  130.000000   TMUS
# 249  2020-12-16  129.809998   TMUS
# 250  2020-12-17  130.009995   TMUS
# 251  2020-12-18  131.919998   TMUS
#
# [1764 rows x 3 columns]

# %%
fig = plt.figure()

for frame in [stock_data_df_AMT, stock_data_df_ADI, stock_data_df_CCI,  stock_data_df_AVGO, stock_data_df_QCOM, stock_data_df_TMUS]:
    plt.plot(frame['Date'], frame['Close'])

#plt.xlim(0,18000)
#plt.ylim(0,30)
plt.show()

# %%
plt.figure()
new_result.plot(x='Date', y='Close')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
for i in [stock_data_df_AMT, stock_data_df_ADI, stock_data_df_CCI, stock_data_df_ERIC, stock_data_df_AVGO, stock_data_df_QCOM, stock_data_df_TMUS]:
    plt.plot(frame['Date'], frame['Close'])

# %%
stock_data = ["Resources/AMT.csv","Resources/ADI.csv"]

dataframes = []

for f in stock_data:
    dataframes.append(pd.read_csv(f))
    
merged_df = pd.concat(dataframes)

print(merged_df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-12-20  226.800003  228.279999  224.500000  227.740005  223.757690
# 1    2019-12-23  227.110001  229.979996  226.399994  226.970001  223.001144
# 2    2019-12-24  227.139999  228.039993  226.259995  227.080002  223.109222
# 3    2019-12-26  226.690002  227.869995  225.570007  227.869995  224.885620
# 4    2019-12-27  228.520004  229.289993  227.550003  229.080002  226.079803
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-12-14  142.059998  143.929993  141.660004  142.330002  142.330002
# 248  2020-12-15  145.259995  145.259995  143.490005  144.059998  144.059998
# 249  2020-12-16  144.759995  144.759995  141.570007  142.800003  142.800003
# 250  2020-12-17  143.550003  143.869995  142.610001  143.779999  143.779999
# 251  2020-12-18  144.380005  145.000000  143.440002  144.559998  144.559998
#
#       Volume
# 0    3333100
# 1    1096400
# ...

# %%
stock_data_all = ["Resources/ADI.csv"]

dataframes = [pd.read_csv(f) for f in stock_data_all]
dataframes
# Out:
# [           Date        Open        High         Low       Close   Adj Close  \
#  0    2019-12-20  120.180000  120.220001  117.900002  119.820000  117.399254
#  1    2019-12-23  120.000000  120.550003  119.029999  119.169998  116.762390
#  2    2019-12-24  119.260002  119.879997  119.110001  119.720001  117.301277
#  3    2019-12-26  119.669998  120.129997  119.260002  119.730003  117.311081
#  4    2019-12-27  119.720001  120.000000  118.989998  119.449997  117.036736
#  ..          ...         ...         ...         ...         ...         ...
#  247  2020-12-14  142.059998  143.929993  141.660004  142.330002  142.330002
#  248  2020-12-15  145.259995  145.259995  143.490005  144.059998  144.059998
#  249  2020-12-16  144.759995  144.759995  141.570007  142.800003  142.800003
#  250  2020-12-17  143.550003  143.869995  142.610001  143.779999  143.779999
#  251  2020-12-18  144.380005  145.000000  143.440002  144.559998  144.559998
#
#        Volume
#  0    4449000
# ...

# %%
"Resources/AMT.csv", 
                  "Resources/AVGO.csv",
                 "Resources/CCI.csv",
                 "Resources/ERIC.csv",
                 "Resources/QCOM.csv",
                 "Resources/TMUS.csv",
# Out:
#   File "<tokenize>", line 3
#     "Resources/CCI.csv",
#     ^
# IndentationError: unindent does not match any outer indentation level
